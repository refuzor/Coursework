# %% [markdown]
# # Ames Housing Price analysis
#
# Author: Matti Kahola
#
# ## TABLE OF CONTENTS:
# 1. [Introduction](#intro)
# 1. [Data import and formatting](#data-format)
# 2. [Data Cleaning](#data-cleaning)
# 3. [Exploratory Data Analysis ](#data-analysis)
# 4. [Data Visualisation](#data-visualisation)
# 5. [Discussion](#discussion)
# 6. [Conclusions](#conclusions)

# %% [markdown]
# ## Intro <a name="intro"></a>

# %% [markdown]
# ## Data import and formatting <a name="data-format"> </a>

# %%
# Importing the packages required for the analysis
import pandas as pd
from urllib.request import urlopen # library for handling url
#import numpy as np

# %%
#Importing data via a unique URL of the file that was saved in dropbox:
#https://www.dropbox.com/s/x61wgiuo299b9tm/AmesHousing.txt?dl=0
url_data = "https://learn-eu-central-1-prod-fleet01-xythos.content.blackboardcdn.com/5c1a4465d06f0/9148720?X-Blackboard-Expiration=1626210000000&X-Blackboard-Signature=omJztPmfIhIBu2uwhiS3FQN3Iep3jka7amzxQjPKBHE%3D&X-Blackboard-Client-Id=100274&response-cache-control=private%2C%20max-age%3D21600&response-content-disposition=inline%3B%20filename%2A%3DUTF-8%27%27AmesHousing.txt&response-content-type=text%2Fplain&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20210713T150000Z&X-Amz-SignedHeaders=host&X-Amz-Expires=21600&X-Amz-Credential=AKIAZH6WM4PL5M5HI5WH%2F20210713%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Signature=ff7313d91e694e38ad92508a4bcdeb57f063c7bb9061144bdadc6fa8572ccf2f"
data = urlopen(url_data).read()

# %%
# ?pd.read_csv
# Out:
# Signature:
# pd.read_csv(
#     filepath_or_buffer: Union[ForwardRef('PathLike[str]'), str, IO[~T], io.RawIOBase, io.BufferedIOBase, io.TextIOBase, _io.TextIOWrapper, mmap.mmap],
#     sep=<object object at 0x00000197ABCD9220>,
#     delimiter=None,
#     header='infer',
#     names=None,
#     index_col=None,
#     usecols=None,
#     squeeze=False,
#     prefix=None,
#     mangle_dupe_cols=True,
#     dtype=None,
#     engine=None,
#     converters=None,
#     true_values=None,
#     false_values=None,
#     skipinitialspace=False,
#     skiprows=None,
#     skipfooter=0,
#     nrows=None,
#     na_values=None,
#     keep_default_na=True,
#     na_filter=True,
#     verbose=False,
#     skip_blank_lines=True,
#     parse_dates=False,
#     infer_datetime_format=False,
#     keep_date_col=False,
#     date_parser=None,
#     dayfirst=False,
#     cache_dates=True,
#     iterator=False,
#     chunksize=None,
#     compression='infer',
#     thousands=None,
#     decimal: str = '.',
# ...

# %%
df = pd.read_csv(data, delimiter ='\t')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-40-c06339399ece> in <module>
# ----> 1 df = pd.read_csv(data, delimiter ='\t')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# ...

# %% [markdown]
# ## Data Cleaning <a name="data-cleaning">  </a>

# %% [markdown]
# ## Exploratory Data Analysis <a name="data-analysis"> </a>

# %% [markdown]
# ## Data Visualisation <a name="data-visualisation"> </a>

# %% [markdown]
# ## Discussion <a name="discussion"> </a>

# %% [markdown]
# ## Conclusions <a name="conclusions"> </a>
